# %%
# %load_ext autoreload
# %autoreload 2

# %%
import modelo_infeccion as mi

# %%
sistemaA = mi.Mundo2d(20,300,0.5)
sistemaB = mi.Mundo2d(10,100,0.9)

# %%
sistemaB.representacion_grafica()

# %%
sistemaA.representacion_grafica()

# %%
sistemaA.infeccion_inicial()

# %%
sistemaA.propagacion()

# %%
sistemaA.representacion_grafica()

# %%
sistemaA.porcentaje_infectado
# Out:
# 0.3453333333333333
