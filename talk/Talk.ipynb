# %%
# %load_ext autoreload
# %autoreload 2

# %%
import modelo_infeccion

# %% [markdown]
# # Una transición de fase en los modelos de propagación o por qué debe quedarse todo el mundo en casa
#
# ## Resumen
#
# La propagación de una infección, un rumor o una señal sobre un conjunto de agentes que interaccionan entre sí es un fenómeno paradigmático clásico en la física de sistemas complejos. Estos sistemas se caracterizan por mostrar una transición de fase que ilustraremos con dos modelos sencillos. Estos nos servirán para comprender por qué casi todos nosotros debemos quedarnos en casa para retardar o detener la propagación del virus SARS-Cov2 mientras unos pocos pueden llevar acabo tareas esenciales, como la atención sanitaria, disminuyendo el riesgo de contagio casi al cero.

# %% [markdown]
# ## Modelo de propagación 2D
#
# - Modelo de percolación

# %%
mundo = modelo_infeccion.Mundo2d(400, 600, ocupacion=0.4)

# %%
mundo.representacion_grafica()
